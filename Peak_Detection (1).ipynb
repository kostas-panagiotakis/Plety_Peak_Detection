# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from sklearn.preprocessing import StandardScaler

import plotly.graph_objects as go

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed, Input
from tensorflow.keras import activations
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from scipy import fftpack

from tensorflow.math import confusion_matrix

# %%
data_1 = pd.read_csv('data/01.csv', sep=',')
data_2 = pd.read_csv('data/02.csv', sep=',')
data_3 = pd.read_csv('data/03.csv', sep=',')
data_4 = pd.read_csv('data/04.csv', sep=',')
data_5 = pd.read_csv('data/05.csv', sep=',')
data_6 = pd.read_csv('data/06.csv', sep=',')
data_7 = pd.read_csv('data/07.csv', sep=',')
data_8 = pd.read_csv('data/08.csv', sep=',')
data_9 = pd.read_csv('data/09.csv', sep=',')
data_10 = pd.read_csv('data/10.csv', sep=',')
data_11 = pd.read_csv('data/11.csv', sep=',')
data_12 = pd.read_csv('data/12.csv', sep=',')
data_13 = pd.read_csv('data/13.csv', sep=',')
data_14 = pd.read_csv('data/14.csv', sep=',')
data_15 = pd.read_csv('data/15.csv', sep=',')
data_16 = pd.read_csv('data/16.csv', sep=',')
data_17 = pd.read_csv('data/17.csv', sep=',')
data_18 = pd.read_csv('data/18.csv', sep=',')
data_19 = pd.read_csv('data/19.csv', sep=',')
data_20 = pd.read_csv('data/20.csv', sep=',')

data_1[['plety','ECG']] -= data_1[['plety','ECG']].mean() 
data_1[['plety','ECG']] /= data_1[['plety','ECG']].std()
data_2[['plety','ECG']] -= data_2[['plety','ECG']].mean() 
data_2[['plety','ECG']] /= data_2[['plety','ECG']].std()
data_3[['plety','ECG']] -= data_3[['plety','ECG']].mean() 
data_3[['plety','ECG']] /= data_3[['plety','ECG']].std()
data_4[['plety','ECG']] -= data_4[['plety','ECG']].mean() 
data_4[['plety','ECG']] /= data_4[['plety','ECG']].std()
data_5[['plety','ECG']] -= data_5[['plety','ECG']].mean() 
data_5[['plety','ECG']] /= data_5[['plety','ECG']].std()
data_6[['plety','ECG']] -= data_6[['plety','ECG']].mean() 
data_6[['plety','ECG']] /= data_6[['plety','ECG']].std()
data_7[['plety','ECG']] -= data_7[['plety','ECG']].mean() 
data_7[['plety','ECG']] /= data_7[['plety','ECG']].std()
data_8[['plety','ECG']] -= data_8[['plety','ECG']].mean() 
data_8[['plety','ECG']] /= data_8[['plety','ECG']].std()
data_9[['plety','ECG']] -= data_9[['plety','ECG']].mean() 
data_9[['plety','ECG']] /= data_9[['plety','ECG']].std()
data_10[['plety','ECG']] -= data_10[['plety','ECG']].mean() 
data_10[['plety','ECG']] /= data_10[['plety','ECG']].std()
data_11[['plety','ECG']] -= data_11[['plety','ECG']].mean() 
data_11[['plety','ECG']] /= data_11[['plety','ECG']].std()
data_12[['plety','ECG']] -= data_12[['plety','ECG']].mean() 
data_12[['plety','ECG']] /= data_12[['plety','ECG']].std()
data_13[['plety','ECG']] -= data_13[['plety','ECG']].mean() 
data_13[['plety','ECG']] /= data_13[['plety','ECG']].std()
data_14[['plety','ECG']] -= data_14[['plety','ECG']].mean() 
data_14[['plety','ECG']] /= data_14[['plety','ECG']].std()
data_15[['plety','ECG']] -= data_15[['plety','ECG']].mean() 
data_15[['plety','ECG']] /= data_15[['plety','ECG']].std()
data_16[['plety','ECG']] -= data_16[['plety','ECG']].mean() 
data_16[['plety','ECG']] /= data_16[['plety','ECG']].std()
data_17[['plety','ECG']] -= data_17[['plety','ECG']].mean() 
data_17[['plety','ECG']] /= data_17[['plety','ECG']].std()
data_18[['plety','ECG']] -= data_18[['plety','ECG']].mean() 
data_18[['plety','ECG']] /= data_18[['plety','ECG']].std()
data_19[['plety','ECG']] -= data_19[['plety','ECG']].mean() 
data_19[['plety','ECG']] /= data_19[['plety','ECG']].std()
data_20[['plety','ECG']] -= data_20[['plety','ECG']].mean() 
data_20[['plety','ECG']] /= data_20[['plety','ECG']].std()

# %%
a_peak = []
x_prime_peak = []

for i in range(1,7):
    # Specify the path to your text file
    file_path_a = "peaks/a_peak_{}.txt".format(i)
    # Specify the path to your text file
    file_path_x_prime = "peaks/x_prime_peak_{}.txt".format(i)

    # Read the contents of the file as a string
    with open(file_path_a, 'r') as file_a:
        a_content = file_a.read()
        
    # Read the contents of the file as a string
    with open(file_path_x_prime, 'r') as file_x_prime:
        x_prime_content = file_x_prime.read()

    # Remove the square brackets and split the string into individual elements
    a_elements = a_content.strip('[]').split(', ')
    x_prime_elements = x_prime_content.strip('[]').split(', ')

    # Convert the elements to integers
    a_peak.append(np.array(a_elements, dtype=int))
    x_prime_peak.append(np.array(x_prime_elements, dtype=int))

# %%
data_1['index_column'] = range(1, len(data_1) + 1)
data_2['index_column'] = range(1, len(data_2) + 1)
data_3['index_column'] = range(1, len(data_3) + 1)
data_4['index_column'] = range(1, len(data_4) + 1)
data_5['index_column'] = range(1, len(data_5) + 1)
data_6['index_column'] = range(1, len(data_6) + 1)
data_7['index_column'] = range(1, len(data_7) + 1)

# Create a new column 'artifacts' with values based on the given list
data_1['a_peak'] = np.where(data_1['index_column'].isin(a_peak[0]), 1, 0)
data_2['a_peak'] = np.where(data_2['index_column'].isin(a_peak[1]), 1, 0)
data_3['a_peak'] = np.where(data_3['index_column'].isin(a_peak[2]), 1, 0)
data_4['a_peak'] = np.where(data_4['index_column'].isin(a_peak[3]), 1, 0)
data_5['a_peak'] = np.where(data_5['index_column'].isin(a_peak[4]), 1, 0)
data_6['a_peak'] = np.where(data_6['index_column'].isin(a_peak[5]), 1, 0)
data_7['a_peak'] = np.where(data_7['index_column'].isin(a_peak[6]), 1, 0)

# Create a new column 'artifacts' with values based on the given list
data_1['x_prime_peak'] = np.where(data_1['index_column'].isin(x_prime_peak[0]), 1, 0)
data_2['x_prime_peak'] = np.where(data_2['index_column'].isin(x_prime_peak[1]), 1, 0)
data_3['x_prime_peak'] = np.where(data_3['index_column'].isin(x_prime_peak[2]), 1, 0)
data_4['x_prime_peak'] = np.where(data_4['index_column'].isin(x_prime_peak[3]), 1, 0)
data_5['x_prime_peak'] = np.where(data_5['index_column'].isin(x_prime_peak[4]), 1, 0)
data_6['x_prime_peak'] = np.where(data_6['index_column'].isin(x_prime_peak[5]), 1, 0)
data_7['x_prime_peak'] = np.where(data_7['index_column'].isin(x_prime_peak[6]), 1, 0)

# %%
df = pd.DataFrame()
df = df.append(data_1) 
df = df.append(data_2) 
df = df.append(data_3) 
df = df.append(data_4) 
df = df.append(data_5) 
df = df.append(data_6)
df = df.append(data_7)
df['indx'] = range(1, len(df) + 1)

# %%
df
# Out:
#            time     plety       ECG  Patient ID  index_column  a_peak  \
# 0      0.000000 -0.037000  1.294023           1             1       0
# 1      0.015003 -0.029710  1.294023           1             2       0
# 2      0.030007 -0.040663  0.846229           1             3       0
# 3      0.045010 -0.077865  0.696966           1             4       0
# 4      0.060013 -0.141235  1.144759           1             5       0
# ...         ...       ...       ...         ...           ...     ...
# 3776  56.654956 -0.591527 -0.219767           6          3777       0
# 3777  56.669960 -0.496703 -0.102299           6          3778       0
# 3778  56.684964 -0.417816 -0.219767           6          3779       0
# 3779  56.699968 -0.365894 -0.196274           6          3780       0
# 3780  56.714972 -0.341283 -0.078807           6          3781       0
#
#       x_prime_peak   indx
# 0                0      1
# 1                0      2
# 2                0      3
# 3                0      4
# 4                0      5
# ...            ...    ...
# 3776             0  22610
# 3777             0  22611
# 3778             0  22612
# 3779             0  22613
# 3780             0  22614
#
# [22614 rows x 8 columns]

# %% [markdown]
# # Peak detection with NN
# ### We tried to build a NN able to detect as many peak as possibile of the typical 6 peaks present in a pletysmography complete cycle. The algorithm was based on supervised learning, with labeled data by hand.

# %%
train = df[(df['Patient ID']<=5)].copy()
test = df[df['Patient ID']==6].copy()
data = pd.DataFrame()

train = train.drop(['time','Patient ID','index_column','indx','x_prime_peak'], axis=1)
test = test.drop(['time','Patient ID','index_column','indx','x_prime_peak'], axis=1)

data = pd.concat([data, train])
data = pd.concat([data, test])
data = np.column_stack((data['plety'], data['ECG'], data['a_peak']))

sequence_length = 30
# create input/output sequences for LSTM
X = []
y = []
for i in range(len(data) - sequence_length):
    X.append(data[i:i+sequence_length, [0,1]])
    y.append(data[i:i+sequence_length, 2])
X = np.array(X)
y = np.array(y)

train_size = int(len(train))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train[np.sum(y_train, axis=1) == 1]
y_train = y_train[np.sum(y_train, axis=1) == 1]

# X_test = X_test[np.sum(y_test, axis=1) == 1]
# y_test = y_test[np.sum(y_test, axis=1) == 1]

permutation_train = np.random.permutation(X_train.shape[0])
X_train= X_train[permutation_train]
y_train = y_train[permutation_train]

print(f'Training shape: {X_train.shape}')
print(f'Testing shape: {X_test.shape}')
# Out:
# Training shape: (8686, 30, 2)
# Testing shape: (3751, 30, 2)

# %%
input_shape = (sequence_length, 2)

print(input_shape)

fc_size = sequence_length

input_data = keras.layers.Input(shape=input_shape, name='input0')

conv1 = keras.layers.Conv1D(sequence_length, 5 , activation='relu',input_shape=input_shape[1:])(input_data)

pool1 = keras.layers.MaxPooling1D(pool_size=2, strides=None, padding='valid', 
                                  data_format='channels_last', name='pool1')(conv1)

conv2 = keras.layers.Conv1D( int(sequence_length/2 ) , 2, activation='relu',input_shape=input_shape[1:])(pool1)

pool2 = keras.layers.MaxPooling1D(pool_size=2, strides=None, padding='valid', data_format='channels_last', name='pool2')(conv2)

flat = keras.layers.Flatten()(pool2)

fc0 = keras.layers.Dense(128, activation=tf.nn.relu,  kernel_initializer='glorot_uniform', bias_initializer='zeros', name='fc0')(flat)

drop2 = keras.layers.Dropout(0.2)

output = keras.layers.Dense(sequence_length, activation=tf.nn.sigmoid, 
                            kernel_initializer='glorot_uniform', bias_initializer='zeros', name='output')(fc0)

model = keras.models.Model(inputs=[input_data], outputs=[output])

model.summary()
# Out:
# (30, 2)
# Model: "model_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input0 (InputLayer)         [(None, 30, 2)]           0
#
#  conv1d_33 (Conv1D)          (None, 26, 30)            330
#
#  pool1 (MaxPooling1D)        (None, 13, 30)            0
#
#  conv1d_34 (Conv1D)          (None, 12, 15)            915
#
#  pool2 (MaxPooling1D)        (None, 6, 15)             0
#
#  flatten_15 (Flatten)        (None, 90)                0
#
#  fc0 (Dense)                 (None, 128)               11648
#
#  output (Dense)              (None, 30)                3870
#
# =================================================================
# Total params: 16,763
# Trainable params: 16,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['FalsePositives'])

history = model.fit(X_train, y_train, epochs=300, validation_split = 0.2)
# Out:
# Epoch 1/300
# 218/218 [==============================] - 2s 4ms/step - loss: 0.1832 - false_positives: 2474.0000 - val_loss: 0.1230 - val_false_positives: 0.0000e+00
# Epoch 2/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.1146 - false_positives: 16.0000 - val_loss: 0.1099 - val_false_positives: 17.0000
# Epoch 3/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.1041 - false_positives: 72.0000 - val_loss: 0.1021 - val_false_positives: 19.0000
# Epoch 4/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0971 - false_positives: 154.0000 - val_loss: 0.0965 - val_false_positives: 41.0000
# Epoch 5/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0919 - false_positives: 229.0000 - val_loss: 0.0913 - val_false_positives: 69.0000
# Epoch 6/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0877 - false_positives: 322.0000 - val_loss: 0.0871 - val_false_positives: 76.0000
# Epoch 7/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0836 - false_positives: 360.0000 - val_loss: 0.0840 - val_false_positives: 85.0000
# Epoch 8/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0804 - false_positives: 424.0000 - val_loss: 0.0819 - val_false_positives: 103.0000
# Epoch 9/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0778 - false_positives: 522.0000 - val_loss: 0.0803 - val_false_positives: 107.0000
# Epoch 10/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0751 - false_positives: 611.0000 - val_loss: 0.0777 - val_false_positives: 171.0000
# Epoch 11/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0731 - false_positives: 646.0000 - val_loss: 0.0751 - val_false_positives: 155.0000
# Epoch 12/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0718 - false_positives: 682.0000 - val_loss: 0.0738 - val_false_positives: 173.0000
# Epoch 13/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0700 - false_positives: 749.0000 - val_loss: 0.0730 - val_false_positives: 179.0000
# Epoch 14/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0684 - false_positives: 783.0000 - val_loss: 0.0724 - val_false_positives: 222.0000
# Epoch 15/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0669 - false_positives: 812.0000 - val_loss: 0.0701 - val_false_positives: 211.0000
# Epoch 16/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0654 - false_positives: 859.0000 - val_loss: 0.0691 - val_false_positives: 226.0000
# Epoch 17/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0643 - false_positives: 929.0000 - val_loss: 0.0691 - val_false_positives: 317.0000
# Epoch 18/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0627 - false_positives: 958.0000 - val_loss: 0.0670 - val_false_positives: 219.0000
# Epoch 19/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0616 - false_positives: 951.0000 - val_loss: 0.0675 - val_false_positives: 301.0000
# Epoch 20/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0608 - false_positives: 1052.0000 - val_loss: 0.0664 - val_false_positives: 290.0000
# Epoch 21/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0593 - false_positives: 986.0000 - val_loss: 0.0653 - val_false_positives: 267.0000
# Epoch 22/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0582 - false_positives: 1047.0000 - val_loss: 0.0662 - val_false_positives: 401.0000
# Epoch 23/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0574 - false_positives: 1106.0000 - val_loss: 0.0637 - val_false_positives: 256.0000
# Epoch 24/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0561 - false_positives: 1084.0000 - val_loss: 0.0633 - val_false_positives: 309.0000
# Epoch 25/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0551 - false_positives: 1098.0000 - val_loss: 0.0622 - val_false_positives: 341.0000
# Epoch 26/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0542 - false_positives: 1123.0000 - val_loss: 0.0624 - val_false_positives: 318.0000
# Epoch 27/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0529 - false_positives: 1093.0000 - val_loss: 0.0615 - val_false_positives: 390.0000
# Epoch 28/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0521 - false_positives: 1156.0000 - val_loss: 0.0610 - val_false_positives: 382.0000
# Epoch 29/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0514 - false_positives: 1169.0000 - val_loss: 0.0608 - val_false_positives: 321.0000
# Epoch 30/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0505 - false_positives: 1175.0000 - val_loss: 0.0606 - val_false_positives: 365.0000
# Epoch 31/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0495 - false_positives: 1152.0000 - val_loss: 0.0599 - val_false_positives: 368.0000
# Epoch 32/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0485 - false_positives: 1155.0000 - val_loss: 0.0607 - val_false_positives: 372.0000
# Epoch 33/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0482 - false_positives: 1201.0000 - val_loss: 0.0604 - val_false_positives: 392.0000
# Epoch 34/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0478 - false_positives: 1207.0000 - val_loss: 0.0579 - val_false_positives: 345.0000
# Epoch 35/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0464 - false_positives: 1174.0000 - val_loss: 0.0607 - val_false_positives: 432.0000
# Epoch 36/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0462 - false_positives: 1202.0000 - val_loss: 0.0589 - val_false_positives: 381.0000
# Epoch 37/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0448 - false_positives: 1161.0000 - val_loss: 0.0592 - val_false_positives: 369.0000
# Epoch 38/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0446 - false_positives: 1216.0000 - val_loss: 0.0583 - val_false_positives: 398.0000
# Epoch 39/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0443 - false_positives: 1178.0000 - val_loss: 0.0572 - val_false_positives: 390.0000
# Epoch 40/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0432 - false_positives: 1144.0000 - val_loss: 0.0574 - val_false_positives: 404.0000
# Epoch 41/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0423 - false_positives: 1158.0000 - val_loss: 0.0584 - val_false_positives: 437.0000
# Epoch 42/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0426 - false_positives: 1204.0000 - val_loss: 0.0565 - val_false_positives: 338.0000
# Epoch 43/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0419 - false_positives: 1247.0000 - val_loss: 0.0560 - val_false_positives: 401.0000
# Epoch 44/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0403 - false_positives: 1117.0000 - val_loss: 0.0563 - val_false_positives: 455.0000
# Epoch 45/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0404 - false_positives: 1173.0000 - val_loss: 0.0564 - val_false_positives: 433.0000
# Epoch 46/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0396 - false_positives: 1125.0000 - val_loss: 0.0573 - val_false_positives: 426.0000
# Epoch 47/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0392 - false_positives: 1169.0000 - val_loss: 0.0564 - val_false_positives: 392.0000
# Epoch 48/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0387 - false_positives: 1170.0000 - val_loss: 0.0574 - val_false_positives: 428.0000
# Epoch 49/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0381 - false_positives: 1122.0000 - val_loss: 0.0564 - val_false_positives: 421.0000
# Epoch 50/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0378 - false_positives: 1156.0000 - val_loss: 0.0572 - val_false_positives: 390.0000
# Epoch 51/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0371 - false_positives: 1122.0000 - val_loss: 0.0564 - val_false_positives: 438.0000
# Epoch 52/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0368 - false_positives: 1134.0000 - val_loss: 0.0576 - val_false_positives: 396.0000
# Epoch 53/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0365 - false_positives: 1126.0000 - val_loss: 0.0564 - val_false_positives: 374.0000
# Epoch 54/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0357 - false_positives: 1109.0000 - val_loss: 0.0568 - val_false_positives: 463.0000
# Epoch 55/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0353 - false_positives: 1106.0000 - val_loss: 0.0590 - val_false_positives: 457.0000
# Epoch 56/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0349 - false_positives: 1072.0000 - val_loss: 0.0575 - val_false_positives: 414.0000
# Epoch 57/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0347 - false_positives: 1050.0000 - val_loss: 0.0556 - val_false_positives: 449.0000
# Epoch 58/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0340 - false_positives: 1081.0000 - val_loss: 0.0590 - val_false_positives: 398.0000
# Epoch 59/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0344 - false_positives: 1063.0000 - val_loss: 0.0601 - val_false_positives: 490.0000
# Epoch 60/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0331 - false_positives: 1048.0000 - val_loss: 0.0579 - val_false_positives: 437.0000
# Epoch 61/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0329 - false_positives: 1069.0000 - val_loss: 0.0575 - val_false_positives: 400.0000
# Epoch 62/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0326 - false_positives: 1041.0000 - val_loss: 0.0584 - val_false_positives: 443.0000
# Epoch 63/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0328 - false_positives: 1110.0000 - val_loss: 0.0600 - val_false_positives: 492.0000
# Epoch 64/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0321 - false_positives: 1015.0000 - val_loss: 0.0577 - val_false_positives: 410.0000
# Epoch 65/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0314 - false_positives: 1000.0000 - val_loss: 0.0591 - val_false_positives: 459.0000
# Epoch 66/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0315 - false_positives: 1004.0000 - val_loss: 0.0599 - val_false_positives: 454.0000
# Epoch 67/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0308 - false_positives: 972.0000 - val_loss: 0.0585 - val_false_positives: 419.0000
# Epoch 68/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0307 - false_positives: 1005.0000 - val_loss: 0.0576 - val_false_positives: 459.0000
# Epoch 69/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0299 - false_positives: 996.0000 - val_loss: 0.0586 - val_false_positives: 433.0000
# Epoch 70/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0299 - false_positives: 1003.0000 - val_loss: 0.0592 - val_false_positives: 393.0000
# Epoch 71/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0296 - false_positives: 985.0000 - val_loss: 0.0603 - val_false_positives: 416.0000
# Epoch 72/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0291 - false_positives: 954.0000 - val_loss: 0.0605 - val_false_positives: 446.0000
# Epoch 73/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0291 - false_positives: 974.0000 - val_loss: 0.0608 - val_false_positives: 453.0000
# Epoch 74/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0286 - false_positives: 953.0000 - val_loss: 0.0615 - val_false_positives: 476.0000
# Epoch 75/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0286 - false_positives: 965.0000 - val_loss: 0.0601 - val_false_positives: 485.0000
# Epoch 76/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0278 - false_positives: 915.0000 - val_loss: 0.0616 - val_false_positives: 468.0000
# Epoch 77/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0283 - false_positives: 970.0000 - val_loss: 0.0637 - val_false_positives: 501.0000
# Epoch 78/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0273 - false_positives: 927.0000 - val_loss: 0.0612 - val_false_positives: 468.0000
# Epoch 79/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0271 - false_positives: 904.0000 - val_loss: 0.0627 - val_false_positives: 475.0000
# Epoch 80/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0267 - false_positives: 877.0000 - val_loss: 0.0608 - val_false_positives: 460.0000
# Epoch 81/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0264 - false_positives: 888.0000 - val_loss: 0.0636 - val_false_positives: 461.0000
# Epoch 82/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0267 - false_positives: 926.0000 - val_loss: 0.0632 - val_false_positives: 475.0000
# Epoch 83/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0258 - false_positives: 878.0000 - val_loss: 0.0634 - val_false_positives: 392.0000
# Epoch 84/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0260 - false_positives: 864.0000 - val_loss: 0.0630 - val_false_positives: 425.0000
# Epoch 85/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0252 - false_positives: 820.0000 - val_loss: 0.0648 - val_false_positives: 427.0000
# Epoch 86/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0252 - false_positives: 839.0000 - val_loss: 0.0631 - val_false_positives: 464.0000
# Epoch 87/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0249 - false_positives: 857.0000 - val_loss: 0.0659 - val_false_positives: 421.0000
# Epoch 88/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0247 - false_positives: 869.0000 - val_loss: 0.0640 - val_false_positives: 482.0000
# Epoch 89/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0244 - false_positives: 829.0000 - val_loss: 0.0684 - val_false_positives: 517.0000
# Epoch 90/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0247 - false_positives: 852.0000 - val_loss: 0.0662 - val_false_positives: 456.0000
# Epoch 91/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0235 - false_positives: 798.0000 - val_loss: 0.0638 - val_false_positives: 438.0000
# Epoch 92/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0241 - false_positives: 845.0000 - val_loss: 0.0676 - val_false_positives: 518.0000
# Epoch 93/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0240 - false_positives: 852.0000 - val_loss: 0.0694 - val_false_positives: 530.0000
# Epoch 94/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0238 - false_positives: 822.0000 - val_loss: 0.0682 - val_false_positives: 474.0000
# Epoch 95/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0233 - false_positives: 807.0000 - val_loss: 0.0668 - val_false_positives: 461.0000
# Epoch 96/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0229 - false_positives: 794.0000 - val_loss: 0.0675 - val_false_positives: 487.0000
# Epoch 97/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0228 - false_positives: 783.0000 - val_loss: 0.0694 - val_false_positives: 447.0000
# Epoch 98/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0224 - false_positives: 772.0000 - val_loss: 0.0684 - val_false_positives: 478.0000
# Epoch 99/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0223 - false_positives: 751.0000 - val_loss: 0.0707 - val_false_positives: 555.0000
# Epoch 100/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0221 - false_positives: 760.0000 - val_loss: 0.0694 - val_false_positives: 486.0000
# Epoch 101/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0215 - false_positives: 727.0000 - val_loss: 0.0708 - val_false_positives: 484.0000
# Epoch 102/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0216 - false_positives: 740.0000 - val_loss: 0.0719 - val_false_positives: 455.0000
# Epoch 103/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0211 - false_positives: 737.0000 - val_loss: 0.0722 - val_false_positives: 518.0000
# Epoch 104/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0219 - false_positives: 784.0000 - val_loss: 0.0717 - val_false_positives: 511.0000
# Epoch 105/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0212 - false_positives: 778.0000 - val_loss: 0.0724 - val_false_positives: 480.0000
# Epoch 106/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0212 - false_positives: 728.0000 - val_loss: 0.0716 - val_false_positives: 460.0000
# Epoch 107/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0207 - false_positives: 693.0000 - val_loss: 0.0736 - val_false_positives: 536.0000
# Epoch 108/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0204 - false_positives: 723.0000 - val_loss: 0.0771 - val_false_positives: 518.0000
# Epoch 109/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0206 - false_positives: 716.0000 - val_loss: 0.0729 - val_false_positives: 486.0000
# Epoch 110/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0197 - false_positives: 665.0000 - val_loss: 0.0734 - val_false_positives: 490.0000
# Epoch 111/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0200 - false_positives: 703.0000 - val_loss: 0.0768 - val_false_positives: 503.0000
# Epoch 112/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0195 - false_positives: 680.0000 - val_loss: 0.0739 - val_false_positives: 488.0000
# Epoch 113/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0198 - false_positives: 692.0000 - val_loss: 0.0752 - val_false_positives: 505.0000
# Epoch 114/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0195 - false_positives: 677.0000 - val_loss: 0.0763 - val_false_positives: 536.0000
# Epoch 115/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0194 - false_positives: 720.0000 - val_loss: 0.0778 - val_false_positives: 501.0000
# Epoch 116/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0192 - false_positives: 675.0000 - val_loss: 0.0775 - val_false_positives: 492.0000
# Epoch 117/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0187 - false_positives: 652.0000 - val_loss: 0.0801 - val_false_positives: 515.0000
# Epoch 118/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0189 - false_positives: 653.0000 - val_loss: 0.0755 - val_false_positives: 531.0000
# Epoch 119/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0182 - false_positives: 626.0000 - val_loss: 0.0784 - val_false_positives: 498.0000
# Epoch 120/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0185 - false_positives: 665.0000 - val_loss: 0.0825 - val_false_positives: 529.0000
# Epoch 121/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0182 - false_positives: 646.0000 - val_loss: 0.0782 - val_false_positives: 461.0000
# Epoch 122/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0179 - false_positives: 612.0000 - val_loss: 0.0795 - val_false_positives: 533.0000
# Epoch 123/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0174 - false_positives: 596.0000 - val_loss: 0.0797 - val_false_positives: 527.0000
# Epoch 124/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0177 - false_positives: 614.0000 - val_loss: 0.0802 - val_false_positives: 494.0000
# Epoch 125/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0167 - false_positives: 599.0000 - val_loss: 0.0812 - val_false_positives: 488.0000
# Epoch 126/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0185 - false_positives: 666.0000 - val_loss: 0.0801 - val_false_positives: 455.0000
# Epoch 127/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0176 - false_positives: 644.0000 - val_loss: 0.0858 - val_false_positives: 498.0000
# Epoch 128/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0169 - false_positives: 601.0000 - val_loss: 0.0851 - val_false_positives: 502.0000
# Epoch 129/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0163 - false_positives: 558.0000 - val_loss: 0.0819 - val_false_positives: 540.0000
# Epoch 130/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0162 - false_positives: 575.0000 - val_loss: 0.0839 - val_false_positives: 517.0000
# Epoch 131/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0166 - false_positives: 577.0000 - val_loss: 0.0819 - val_false_positives: 476.0000
# Epoch 132/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0167 - false_positives: 582.0000 - val_loss: 0.0855 - val_false_positives: 555.0000
# Epoch 133/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0163 - false_positives: 547.0000 - val_loss: 0.0851 - val_false_positives: 575.0000
# Epoch 134/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0162 - false_positives: 580.0000 - val_loss: 0.0856 - val_false_positives: 532.0000
# Epoch 135/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0162 - false_positives: 577.0000 - val_loss: 0.0871 - val_false_positives: 516.0000
# Epoch 136/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0164 - false_positives: 602.0000 - val_loss: 0.0867 - val_false_positives: 541.0000
# Epoch 137/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0158 - false_positives: 559.0000 - val_loss: 0.0881 - val_false_positives: 545.0000
# Epoch 138/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0149 - false_positives: 505.0000 - val_loss: 0.0883 - val_false_positives: 521.0000
# Epoch 139/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0152 - false_positives: 508.0000 - val_loss: 0.0874 - val_false_positives: 493.0000
# Epoch 140/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0159 - false_positives: 573.0000 - val_loss: 0.0922 - val_false_positives: 504.0000
# Epoch 141/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0150 - false_positives: 526.0000 - val_loss: 0.0909 - val_false_positives: 494.0000
# Epoch 142/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0146 - false_positives: 488.0000 - val_loss: 0.0918 - val_false_positives: 526.0000
# Epoch 143/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0147 - false_positives: 521.0000 - val_loss: 0.0922 - val_false_positives: 510.0000
# Epoch 144/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0149 - false_positives: 518.0000 - val_loss: 0.0927 - val_false_positives: 487.0000
# Epoch 145/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0141 - false_positives: 487.0000 - val_loss: 0.0919 - val_false_positives: 516.0000
# Epoch 146/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0157 - false_positives: 579.0000 - val_loss: 0.0938 - val_false_positives: 533.0000
# Epoch 147/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0151 - false_positives: 554.0000 - val_loss: 0.0935 - val_false_positives: 508.0000
# Epoch 148/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0141 - false_positives: 494.0000 - val_loss: 0.0942 - val_false_positives: 537.0000
# Epoch 149/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0137 - false_positives: 460.0000 - val_loss: 0.0944 - val_false_positives: 471.0000
# Epoch 150/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0137 - false_positives: 480.0000 - val_loss: 0.0946 - val_false_positives: 539.0000
# Epoch 151/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0138 - false_positives: 473.0000 - val_loss: 0.0955 - val_false_positives: 535.0000
# Epoch 152/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0136 - false_positives: 485.0000 - val_loss: 0.0963 - val_false_positives: 510.0000
# Epoch 153/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0127 - false_positives: 429.0000 - val_loss: 0.0983 - val_false_positives: 493.0000
# Epoch 154/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0133 - false_positives: 476.0000 - val_loss: 0.0983 - val_false_positives: 562.0000
# Epoch 155/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0132 - false_positives: 474.0000 - val_loss: 0.0974 - val_false_positives: 544.0000
# Epoch 156/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0148 - false_positives: 529.0000 - val_loss: 0.0988 - val_false_positives: 532.0000
# Epoch 157/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0139 - false_positives: 513.0000 - val_loss: 0.0986 - val_false_positives: 563.0000
# Epoch 158/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0131 - false_positives: 457.0000 - val_loss: 0.0986 - val_false_positives: 557.0000
# Epoch 159/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0120 - false_positives: 387.0000 - val_loss: 0.1006 - val_false_positives: 519.0000
# Epoch 160/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0123 - false_positives: 428.0000 - val_loss: 0.1012 - val_false_positives: 541.0000
# Epoch 161/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0126 - false_positives: 465.0000 - val_loss: 0.1033 - val_false_positives: 547.0000
# Epoch 162/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0125 - false_positives: 418.0000 - val_loss: 0.1017 - val_false_positives: 513.0000
# Epoch 163/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0124 - false_positives: 440.0000 - val_loss: 0.1050 - val_false_positives: 530.0000
# Epoch 164/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0126 - false_positives: 463.0000 - val_loss: 0.1028 - val_false_positives: 544.0000
# Epoch 165/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0120 - false_positives: 411.0000 - val_loss: 0.1076 - val_false_positives: 526.0000
# Epoch 166/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0125 - false_positives: 460.0000 - val_loss: 0.1027 - val_false_positives: 527.0000
# Epoch 167/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0116 - false_positives: 404.0000 - val_loss: 0.1046 - val_false_positives: 526.0000
# Epoch 168/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0123 - false_positives: 419.0000 - val_loss: 0.1062 - val_false_positives: 557.0000
# Epoch 169/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0113 - false_positives: 394.0000 - val_loss: 0.1058 - val_false_positives: 510.0000
# Epoch 170/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0118 - false_positives: 435.0000 - val_loss: 0.1085 - val_false_positives: 564.0000
# Epoch 171/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0123 - false_positives: 429.0000 - val_loss: 0.1089 - val_false_positives: 547.0000
# Epoch 172/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0132 - false_positives: 494.0000 - val_loss: 0.1065 - val_false_positives: 515.0000
# Epoch 173/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0114 - false_positives: 399.0000 - val_loss: 0.1077 - val_false_positives: 536.0000
# Epoch 174/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0115 - false_positives: 390.0000 - val_loss: 0.1098 - val_false_positives: 548.0000
# Epoch 175/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0112 - false_positives: 405.0000 - val_loss: 0.1140 - val_false_positives: 558.0000
# Epoch 176/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0111 - false_positives: 389.0000 - val_loss: 0.1125 - val_false_positives: 583.0000
# Epoch 177/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0116 - false_positives: 402.0000 - val_loss: 0.1139 - val_false_positives: 513.0000
# Epoch 178/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0112 - false_positives: 385.0000 - val_loss: 0.1118 - val_false_positives: 518.0000
# Epoch 179/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0107 - false_positives: 362.0000 - val_loss: 0.1141 - val_false_positives: 551.0000
# Epoch 180/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0106 - false_positives: 364.0000 - val_loss: 0.1160 - val_false_positives: 549.0000
# Epoch 181/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0108 - false_positives: 341.0000 - val_loss: 0.1182 - val_false_positives: 600.0000
# Epoch 182/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0111 - false_positives: 408.0000 - val_loss: 0.1136 - val_false_positives: 530.0000
# Epoch 183/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0103 - false_positives: 354.0000 - val_loss: 0.1193 - val_false_positives: 577.0000
# Epoch 184/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0110 - false_positives: 396.0000 - val_loss: 0.1181 - val_false_positives: 543.0000
# Epoch 185/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0112 - false_positives: 391.0000 - val_loss: 0.1170 - val_false_positives: 546.0000
# Epoch 186/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0097 - false_positives: 323.0000 - val_loss: 0.1164 - val_false_positives: 563.0000
# Epoch 187/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0094 - false_positives: 322.0000 - val_loss: 0.1163 - val_false_positives: 499.0000
# Epoch 188/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0100 - false_positives: 357.0000 - val_loss: 0.1180 - val_false_positives: 561.0000
# Epoch 189/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0103 - false_positives: 361.0000 - val_loss: 0.1212 - val_false_positives: 545.0000
# Epoch 190/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0109 - false_positives: 392.0000 - val_loss: 0.1228 - val_false_positives: 525.0000
# Epoch 191/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0097 - false_positives: 303.0000 - val_loss: 0.1211 - val_false_positives: 529.0000
# Epoch 192/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0105 - false_positives: 378.0000 - val_loss: 0.1273 - val_false_positives: 603.0000
# Epoch 193/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0105 - false_positives: 367.0000 - val_loss: 0.1215 - val_false_positives: 547.0000
# Epoch 194/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0097 - false_positives: 336.0000 - val_loss: 0.1243 - val_false_positives: 536.0000
# Epoch 195/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0089 - false_positives: 309.0000 - val_loss: 0.1291 - val_false_positives: 546.0000
# Epoch 196/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0094 - false_positives: 333.0000 - val_loss: 0.1229 - val_false_positives: 531.0000
# Epoch 197/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0104 - false_positives: 358.0000 - val_loss: 0.1267 - val_false_positives: 507.0000
# Epoch 198/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0098 - false_positives: 345.0000 - val_loss: 0.1242 - val_false_positives: 553.0000
# Epoch 199/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0090 - false_positives: 327.0000 - val_loss: 0.1254 - val_false_positives: 522.0000
# Epoch 200/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0094 - false_positives: 322.0000 - val_loss: 0.1244 - val_false_positives: 570.0000
# Epoch 201/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0084 - false_positives: 294.0000 - val_loss: 0.1292 - val_false_positives: 550.0000
# Epoch 202/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0104 - false_positives: 382.0000 - val_loss: 0.1302 - val_false_positives: 548.0000
# Epoch 203/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0085 - false_positives: 289.0000 - val_loss: 0.1300 - val_false_positives: 556.0000
# Epoch 204/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0094 - false_positives: 324.0000 - val_loss: 0.1263 - val_false_positives: 494.0000
# Epoch 205/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0083 - false_positives: 299.0000 - val_loss: 0.1285 - val_false_positives: 532.0000
# Epoch 206/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0090 - false_positives: 309.0000 - val_loss: 0.1280 - val_false_positives: 518.0000
# Epoch 207/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0102 - false_positives: 372.0000 - val_loss: 0.1322 - val_false_positives: 535.0000
# Epoch 208/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0085 - false_positives: 282.0000 - val_loss: 0.1277 - val_false_positives: 523.0000
# Epoch 209/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0078 - false_positives: 244.0000 - val_loss: 0.1303 - val_false_positives: 609.0000
# Epoch 210/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0082 - false_positives: 290.0000 - val_loss: 0.1370 - val_false_positives: 542.0000
# Epoch 211/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0087 - false_positives: 311.0000 - val_loss: 0.1317 - val_false_positives: 539.0000
# Epoch 212/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0090 - false_positives: 336.0000 - val_loss: 0.1360 - val_false_positives: 541.0000
# Epoch 213/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0090 - false_positives: 327.0000 - val_loss: 0.1324 - val_false_positives: 519.0000
# Epoch 214/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0088 - false_positives: 330.0000 - val_loss: 0.1344 - val_false_positives: 556.0000
# Epoch 215/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0081 - false_positives: 270.0000 - val_loss: 0.1344 - val_false_positives: 590.0000
# Epoch 216/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0078 - false_positives: 261.0000 - val_loss: 0.1351 - val_false_positives: 520.0000
# Epoch 217/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0076 - false_positives: 255.0000 - val_loss: 0.1336 - val_false_positives: 554.0000
# Epoch 218/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0081 - false_positives: 291.0000 - val_loss: 0.1349 - val_false_positives: 537.0000
# Epoch 219/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0081 - false_positives: 251.0000 - val_loss: 0.1352 - val_false_positives: 546.0000
# Epoch 220/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0102 - false_positives: 383.0000 - val_loss: 0.1370 - val_false_positives: 567.0000
# Epoch 221/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0080 - false_positives: 265.0000 - val_loss: 0.1406 - val_false_positives: 518.0000
# Epoch 222/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0120 - false_positives: 430.0000 - val_loss: 0.1365 - val_false_positives: 512.0000
# Epoch 223/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0075 - false_positives: 246.0000 - val_loss: 0.1389 - val_false_positives: 546.0000
# Epoch 224/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0064 - false_positives: 190.0000 - val_loss: 0.1400 - val_false_positives: 525.0000
# Epoch 225/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0069 - false_positives: 215.0000 - val_loss: 0.1376 - val_false_positives: 523.0000
# Epoch 226/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0074 - false_positives: 233.0000 - val_loss: 0.1411 - val_false_positives: 558.0000
# Epoch 227/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 249.0000 - val_loss: 0.1447 - val_false_positives: 570.0000
# Epoch 228/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0091 - false_positives: 318.0000 - val_loss: 0.1440 - val_false_positives: 522.0000
# Epoch 229/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0078 - false_positives: 265.0000 - val_loss: 0.1442 - val_false_positives: 543.0000
# Epoch 230/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0068 - false_positives: 222.0000 - val_loss: 0.1466 - val_false_positives: 561.0000
# Epoch 231/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0068 - false_positives: 227.0000 - val_loss: 0.1439 - val_false_positives: 516.0000
# Epoch 232/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0068 - false_positives: 237.0000 - val_loss: 0.1445 - val_false_positives: 557.0000
# Epoch 233/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0090 - false_positives: 320.0000 - val_loss: 0.1475 - val_false_positives: 572.0000
# Epoch 234/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0085 - false_positives: 318.0000 - val_loss: 0.1477 - val_false_positives: 576.0000
# Epoch 235/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 255.0000 - val_loss: 0.1440 - val_false_positives: 570.0000
# Epoch 236/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0058 - false_positives: 179.0000 - val_loss: 0.1482 - val_false_positives: 533.0000
# Epoch 237/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0065 - false_positives: 224.0000 - val_loss: 0.1491 - val_false_positives: 562.0000
# Epoch 238/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 262.0000 - val_loss: 0.1490 - val_false_positives: 553.0000
# Epoch 239/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0062 - false_positives: 190.0000 - val_loss: 0.1497 - val_false_positives: 559.0000
# Epoch 240/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0061 - false_positives: 198.0000 - val_loss: 0.1500 - val_false_positives: 548.0000
# Epoch 241/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 254.0000 - val_loss: 0.1527 - val_false_positives: 587.0000
# Epoch 242/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 244.0000 - val_loss: 0.1512 - val_false_positives: 568.0000
# Epoch 243/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0064 - false_positives: 220.0000 - val_loss: 0.1530 - val_false_positives: 535.0000
# Epoch 244/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 265.0000 - val_loss: 0.1557 - val_false_positives: 546.0000
# Epoch 245/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0085 - false_positives: 316.0000 - val_loss: 0.1525 - val_false_positives: 572.0000
# Epoch 246/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0082 - false_positives: 299.0000 - val_loss: 0.1540 - val_false_positives: 577.0000
# Epoch 247/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0076 - false_positives: 287.0000 - val_loss: 0.1526 - val_false_positives: 545.0000
# Epoch 248/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0058 - false_positives: 180.0000 - val_loss: 0.1538 - val_false_positives: 589.0000
# Epoch 249/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0058 - false_positives: 195.0000 - val_loss: 0.1519 - val_false_positives: 566.0000
# Epoch 250/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 264.0000 - val_loss: 0.1557 - val_false_positives: 528.0000
# Epoch 251/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0066 - false_positives: 232.0000 - val_loss: 0.1551 - val_false_positives: 594.0000
# Epoch 252/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0063 - false_positives: 215.0000 - val_loss: 0.1600 - val_false_positives: 537.0000
# Epoch 253/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0074 - false_positives: 247.0000 - val_loss: 0.1592 - val_false_positives: 582.0000
# Epoch 254/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0063 - false_positives: 216.0000 - val_loss: 0.1601 - val_false_positives: 553.0000
# Epoch 255/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0060 - false_positives: 200.0000 - val_loss: 0.1546 - val_false_positives: 583.0000
# Epoch 256/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0059 - false_positives: 210.0000 - val_loss: 0.1602 - val_false_positives: 583.0000
# Epoch 257/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 267.0000 - val_loss: 0.1611 - val_false_positives: 545.0000
# Epoch 258/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0078 - false_positives: 292.0000 - val_loss: 0.1632 - val_false_positives: 594.0000
# Epoch 259/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0060 - false_positives: 222.0000 - val_loss: 0.1597 - val_false_positives: 547.0000
# Epoch 260/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0063 - false_positives: 221.0000 - val_loss: 0.1622 - val_false_positives: 554.0000
# Epoch 261/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 174.0000 - val_loss: 0.1627 - val_false_positives: 602.0000
# Epoch 262/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0068 - false_positives: 227.0000 - val_loss: 0.1623 - val_false_positives: 619.0000
# Epoch 263/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0061 - false_positives: 206.0000 - val_loss: 0.1634 - val_false_positives: 556.0000
# Epoch 264/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 187.0000 - val_loss: 0.1648 - val_false_positives: 567.0000
# Epoch 265/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0058 - false_positives: 214.0000 - val_loss: 0.1653 - val_false_positives: 542.0000
# Epoch 266/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0066 - false_positives: 245.0000 - val_loss: 0.1658 - val_false_positives: 604.0000
# Epoch 267/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0067 - false_positives: 237.0000 - val_loss: 0.1693 - val_false_positives: 621.0000
# Epoch 268/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 258.0000 - val_loss: 0.1663 - val_false_positives: 629.0000
# Epoch 269/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 167.0000 - val_loss: 0.1681 - val_false_positives: 570.0000
# Epoch 270/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0066 - false_positives: 232.0000 - val_loss: 0.1671 - val_false_positives: 569.0000
# Epoch 271/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0057 - false_positives: 199.0000 - val_loss: 0.1705 - val_false_positives: 529.0000
# Epoch 272/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0057 - false_positives: 190.0000 - val_loss: 0.1678 - val_false_positives: 536.0000
# Epoch 273/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0071 - false_positives: 248.0000 - val_loss: 0.1693 - val_false_positives: 541.0000
# Epoch 274/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0056 - false_positives: 194.0000 - val_loss: 0.1642 - val_false_positives: 586.0000
# Epoch 275/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0062 - false_positives: 212.0000 - val_loss: 0.1666 - val_false_positives: 575.0000
# Epoch 276/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0050 - false_positives: 155.0000 - val_loss: 0.1681 - val_false_positives: 545.0000
# Epoch 277/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0046 - false_positives: 137.0000 - val_loss: 0.1747 - val_false_positives: 570.0000
# Epoch 278/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0047 - false_positives: 161.0000 - val_loss: 0.1738 - val_false_positives: 549.0000
# Epoch 279/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0069 - false_positives: 236.0000 - val_loss: 0.1775 - val_false_positives: 550.0000
# Epoch 280/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0080 - false_positives: 308.0000 - val_loss: 0.1760 - val_false_positives: 578.0000
# Epoch 281/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0052 - false_positives: 194.0000 - val_loss: 0.1809 - val_false_positives: 583.0000
# Epoch 282/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 169.0000 - val_loss: 0.1726 - val_false_positives: 608.0000
# Epoch 283/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0044 - false_positives: 138.0000 - val_loss: 0.1729 - val_false_positives: 558.0000
# Epoch 284/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0045 - false_positives: 131.0000 - val_loss: 0.1729 - val_false_positives: 574.0000
# Epoch 285/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0048 - false_positives: 172.0000 - val_loss: 0.1739 - val_false_positives: 599.0000
# Epoch 286/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 174.0000 - val_loss: 0.1789 - val_false_positives: 635.0000
# Epoch 287/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0077 - false_positives: 261.0000 - val_loss: 0.1832 - val_false_positives: 571.0000
# Epoch 288/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0070 - false_positives: 244.0000 - val_loss: 0.1770 - val_false_positives: 611.0000
# Epoch 289/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0050 - false_positives: 178.0000 - val_loss: 0.1764 - val_false_positives: 604.0000
# Epoch 290/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0040 - false_positives: 124.0000 - val_loss: 0.1784 - val_false_positives: 559.0000
# Epoch 291/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0055 - false_positives: 192.0000 - val_loss: 0.1789 - val_false_positives: 597.0000
# Epoch 292/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0055 - false_positives: 186.0000 - val_loss: 0.1817 - val_false_positives: 589.0000
# Epoch 293/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0056 - false_positives: 205.0000 - val_loss: 0.1775 - val_false_positives: 520.0000
# Epoch 294/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0075 - false_positives: 244.0000 - val_loss: 0.1843 - val_false_positives: 608.0000
# Epoch 295/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0063 - false_positives: 240.0000 - val_loss: 0.1814 - val_false_positives: 566.0000
# Epoch 296/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0042 - false_positives: 122.0000 - val_loss: 0.1784 - val_false_positives: 586.0000
# Epoch 297/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0043 - false_positives: 145.0000 - val_loss: 0.1767 - val_false_positives: 578.0000
# Epoch 298/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0035 - false_positives: 102.0000 - val_loss: 0.1821 - val_false_positives: 536.0000
# Epoch 299/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0039 - false_positives: 128.0000 - val_loss: 0.1852 - val_false_positives: 574.0000
# Epoch 300/300
# 218/218 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 259.0000 - val_loss: 0.1895 - val_false_positives: 601.0000

# %%
pred_y = model.predict(X_test)
# Out:
# 118/118 [==============================] - 0s 1ms/step

# %%
c = 9

plt.plot(y_test[sequence_length*c])
plt.plot(pred_y[sequence_length*c])

# %%
# Get the plethysmographic data and remove the last element for shape purposes
plety = test['plety'].iloc[:-1]


# Calculate actual peak values from the test data
actual_values = plety[test['a_peak']==1]

# Calculate the indeces where the actual values are present 
# so that we can plot the point from the test at that index
indices = actual_values.index

# Calculate the predictions:
# We have 3700+ sequences of 60 points
# The first sequence of 60 points is saved in the predictions array
# for each one of the net sequences we save the last element to the array
# we end up with a prediction array with all the predicted values for each plety index value
predictions = np.array([])

for ind, i in enumerate(pred_y):
    if ind == 0:
        predictions = np.append(predictions, pred_y[ind])
    else:
        predictions = np.append(predictions, pred_y[ind][-1])
        
# Calculate the indeces where the predicted values are present 
# so that we can plot the point from the test at that index
indices_pred = np.where(np.isin(predictions, predictions[predictions>0.5]))[0]

range_min = 0
range_max = 1500

# Set the figure size
plt.figure(figsize=(20, 10))

# Plotting code
# Plot the plety data
plt.plot(plety[range_min:range_max])

# Plot the points from the plety where actual values have a peak, (==1)
plt.scatter(np.array(indices[indices<range_max]), actual_values[range_min:len(np.array(indices[indices<range_max]))], c="black", label='actual')

# Plot the points from the plety where predicted values have a peak, (==1)
plt.scatter(np.array(indices_pred[indices_pred<range_max]), plety[indices_pred][range_min:len(np.array(indices_pred[indices_pred<range_max]))],c="red", label='predicted')

# Display the legend
plt.legend()

plt.show()

# %%
pred_y = model.predict(X_test) > 0.5
# Out:
# 118/118 [==============================] - 0s 1ms/step

# %%
import seaborn as sns

y_test = y_test.flatten()
pred_y = pred_y.flatten()

mat = np.array(confusion_matrix(y_test, pred_y), dtype=float)
mat[0,0] = mat[0,0]/len(y_test[y_test == 0])
mat[1,1] = mat[1,1]/len(y_test[y_test == 1])

mat[0,1] = mat[0,1]/len(y_test[y_test == 0])
mat[1,0] = mat[1,0]/len(y_test[y_test == 1])
labels = ['0', '1']

sns.heatmap(mat, square=True, annot=True, cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
plt.show()

# %% [markdown]
# ## X_prime

# %%
train = df[(df['Patient ID']<=5)].copy()
test = df[df['Patient ID']==6].copy()
data = pd.DataFrame()

train = train.drop(['time','Patient ID','index_column','indx','a_peak'], axis=1)
test = test.drop(['time','Patient ID','index_column','indx','a_peak'], axis=1)

data = pd.concat([data, train])
data = pd.concat([data, test])
data = np.column_stack((data['plety'], data['ECG'], data['x_prime_peak']))

sequence_length = 30
# create input/output sequences for LSTM
X = []
y = []
for i in range(len(data) - sequence_length):
    X.append(data[i:i+sequence_length, [0,1]])
    y.append(data[i:i+sequence_length, 2])
X = np.array(X)
y = np.array(y)

train_size = int(len(train))
X_train, X_test = X[:train_size], X[train_size:]
y_train, y_test = y[:train_size], y[train_size:]

X_train = X_train[np.sum(y_train, axis=1) == 1]
y_train = y_train[np.sum(y_train, axis=1) == 1]

# X_test = X_test[np.sum(y_test, axis=1) == 1]
# y_test = y_test[np.sum(y_test, axis=1) == 1]

permutation_train = np.random.permutation(X_train.shape[0])
X_train= X_train[permutation_train]
y_train = y_train[permutation_train]

print(f'Training shape: {X_train.shape}')
print(f'Testing shape: {X_test.shape}')
# Out:
# Training shape: (8642, 30, 2)
# Testing shape: (3751, 30, 2)

# %%
input_shape = (sequence_length, 2)

print(input_shape)

fc_size = sequence_length

input_data = keras.layers.Input(shape=input_shape, name='input0')

conv1 = keras.layers.Conv1D(sequence_length, 5 , activation='relu',input_shape=input_shape[1:])(input_data)

pool1 = keras.layers.MaxPooling1D(pool_size=2, strides=None, padding='valid', 
                                  data_format='channels_last', name='pool1')(conv1)

conv2 = keras.layers.Conv1D( int(sequence_length/2 ) , 2, activation='relu',input_shape=input_shape[1:])(pool1)

pool2 = keras.layers.MaxPooling1D(pool_size=2, strides=None, padding='valid', data_format='channels_last', name='pool2')(conv2)

flat = keras.layers.Flatten()(pool2)

fc0 = keras.layers.Dense(128, activation=tf.nn.relu,  kernel_initializer='glorot_uniform', bias_initializer='zeros', name='fc0')(flat)

drop2 = keras.layers.Dropout(0.2)

output = keras.layers.Dense(sequence_length, activation=tf.nn.sigmoid, 
                            kernel_initializer='glorot_uniform', bias_initializer='zeros', name='output')(fc0)

model = keras.models.Model(inputs=[input_data], outputs=[output])

model.summary()
# Out:
# (30, 2)
# Model: "model_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input0 (InputLayer)         [(None, 30, 2)]           0
#
#  conv1d_31 (Conv1D)          (None, 26, 30)            330
#
#  pool1 (MaxPooling1D)        (None, 13, 30)            0
#
#  conv1d_32 (Conv1D)          (None, 12, 15)            915
#
#  pool2 (MaxPooling1D)        (None, 6, 15)             0
#
#  flatten_14 (Flatten)        (None, 90)                0
#
#  fc0 (Dense)                 (None, 128)               11648
#
#  output (Dense)              (None, 30)                3870
#
# =================================================================
# Total params: 16,763
# Trainable params: 16,763
# Non-trainable params: 0
# _________________________________________________________________

# %%
adam = keras.optimizers.Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999)

model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['FalsePositives'])

history = model.fit(X_train, y_train, epochs=300, validation_split = 0.2)
# Out:
# Epoch 1/300
# 217/217 [==============================] - 2s 5ms/step - loss: 0.1814 - false_positives: 2871.0000 - val_loss: 0.1161 - val_false_positives: 1.0000
# Epoch 2/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.1087 - false_positives: 38.0000 - val_loss: 0.1030 - val_false_positives: 26.0000
# Epoch 3/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0988 - false_positives: 135.0000 - val_loss: 0.0940 - val_false_positives: 23.0000
# Epoch 4/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0914 - false_positives: 245.0000 - val_loss: 0.0879 - val_false_positives: 97.0000
# Epoch 5/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0858 - false_positives: 386.0000 - val_loss: 0.0833 - val_false_positives: 152.0000
# Epoch 6/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0812 - false_positives: 525.0000 - val_loss: 0.0791 - val_false_positives: 113.0000
# Epoch 7/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0769 - false_positives: 621.0000 - val_loss: 0.0766 - val_false_positives: 163.0000
# Epoch 8/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0730 - false_positives: 668.0000 - val_loss: 0.0729 - val_false_positives: 254.0000
# Epoch 9/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0699 - false_positives: 810.0000 - val_loss: 0.0710 - val_false_positives: 247.0000
# Epoch 10/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0674 - false_positives: 889.0000 - val_loss: 0.0689 - val_false_positives: 264.0000
# Epoch 11/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0643 - false_positives: 923.0000 - val_loss: 0.0655 - val_false_positives: 223.0000
# Epoch 12/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0623 - false_positives: 990.0000 - val_loss: 0.0646 - val_false_positives: 273.0000
# Epoch 13/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0603 - false_positives: 1008.0000 - val_loss: 0.0630 - val_false_positives: 270.0000
# Epoch 14/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0583 - false_positives: 1033.0000 - val_loss: 0.0625 - val_false_positives: 296.0000
# Epoch 15/300
# 217/217 [==============================] - 1s 2ms/step - loss: 0.0571 - false_positives: 1122.0000 - val_loss: 0.0620 - val_false_positives: 342.0000
# Epoch 16/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0559 - false_positives: 1112.0000 - val_loss: 0.0611 - val_false_positives: 273.0000
# Epoch 17/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0539 - false_positives: 1051.0000 - val_loss: 0.0594 - val_false_positives: 298.0000
# Epoch 18/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0527 - false_positives: 1161.0000 - val_loss: 0.0596 - val_false_positives: 373.0000
# Epoch 19/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0514 - false_positives: 1125.0000 - val_loss: 0.0609 - val_false_positives: 371.0000
# Epoch 20/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0503 - false_positives: 1133.0000 - val_loss: 0.0582 - val_false_positives: 329.0000
# Epoch 21/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0500 - false_positives: 1182.0000 - val_loss: 0.0579 - val_false_positives: 373.0000
# Epoch 22/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0482 - false_positives: 1123.0000 - val_loss: 0.0569 - val_false_positives: 316.0000
# Epoch 23/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0471 - false_positives: 1137.0000 - val_loss: 0.0577 - val_false_positives: 340.0000
# Epoch 24/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0463 - false_positives: 1163.0000 - val_loss: 0.0561 - val_false_positives: 416.0000
# Epoch 25/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0456 - false_positives: 1153.0000 - val_loss: 0.0571 - val_false_positives: 395.0000
# Epoch 26/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0446 - false_positives: 1183.0000 - val_loss: 0.0563 - val_false_positives: 358.0000
# Epoch 27/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0438 - false_positives: 1161.0000 - val_loss: 0.0559 - val_false_positives: 384.0000
# Epoch 28/300
# 217/217 [==============================] - 1s 2ms/step - loss: 0.0435 - false_positives: 1149.0000 - val_loss: 0.0558 - val_false_positives: 405.0000
# Epoch 29/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0420 - false_positives: 1109.0000 - val_loss: 0.0561 - val_false_positives: 375.0000
# Epoch 30/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0419 - false_positives: 1146.0000 - val_loss: 0.0560 - val_false_positives: 411.0000
# Epoch 31/300
# 217/217 [==============================] - 1s 2ms/step - loss: 0.0415 - false_positives: 1192.0000 - val_loss: 0.0568 - val_false_positives: 367.0000
# Epoch 32/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0413 - false_positives: 1172.0000 - val_loss: 0.0560 - val_false_positives: 383.0000
# Epoch 33/300
# 217/217 [==============================] - 1s 2ms/step - loss: 0.0405 - false_positives: 1181.0000 - val_loss: 0.0600 - val_false_positives: 442.0000
# Epoch 34/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0418 - false_positives: 1174.0000 - val_loss: 0.0556 - val_false_positives: 350.0000
# Epoch 35/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0385 - false_positives: 1099.0000 - val_loss: 0.0576 - val_false_positives: 381.0000
# Epoch 36/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0378 - false_positives: 1068.0000 - val_loss: 0.0560 - val_false_positives: 377.0000
# Epoch 37/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0376 - false_positives: 1051.0000 - val_loss: 0.0560 - val_false_positives: 396.0000
# Epoch 38/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0376 - false_positives: 1136.0000 - val_loss: 0.0558 - val_false_positives: 365.0000
# Epoch 39/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0367 - false_positives: 1073.0000 - val_loss: 0.0582 - val_false_positives: 374.0000
# Epoch 40/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0365 - false_positives: 1095.0000 - val_loss: 0.0562 - val_false_positives: 384.0000
# Epoch 41/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0357 - false_positives: 1065.0000 - val_loss: 0.0569 - val_false_positives: 397.0000
# Epoch 42/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0358 - false_positives: 1091.0000 - val_loss: 0.0565 - val_false_positives: 369.0000
# Epoch 43/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0347 - false_positives: 1060.0000 - val_loss: 0.0564 - val_false_positives: 352.0000
# Epoch 44/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0343 - false_positives: 1071.0000 - val_loss: 0.0611 - val_false_positives: 452.0000
# Epoch 45/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0351 - false_positives: 1093.0000 - val_loss: 0.0569 - val_false_positives: 342.0000
# Epoch 46/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0341 - false_positives: 1096.0000 - val_loss: 0.0570 - val_false_positives: 363.0000
# Epoch 47/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0330 - false_positives: 1041.0000 - val_loss: 0.0580 - val_false_positives: 413.0000
# Epoch 48/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0329 - false_positives: 1039.0000 - val_loss: 0.0587 - val_false_positives: 409.0000
# Epoch 49/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0324 - false_positives: 1025.0000 - val_loss: 0.0596 - val_false_positives: 422.0000
# Epoch 50/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0319 - false_positives: 1010.0000 - val_loss: 0.0589 - val_false_positives: 341.0000
# Epoch 51/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0318 - false_positives: 1015.0000 - val_loss: 0.0591 - val_false_positives: 419.0000
# Epoch 52/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0313 - false_positives: 1033.0000 - val_loss: 0.0603 - val_false_positives: 375.0000
# Epoch 53/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0311 - false_positives: 1028.0000 - val_loss: 0.0603 - val_false_positives: 400.0000
# Epoch 54/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0302 - false_positives: 985.0000 - val_loss: 0.0608 - val_false_positives: 442.0000
# Epoch 55/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0303 - false_positives: 1010.0000 - val_loss: 0.0596 - val_false_positives: 413.0000
# Epoch 56/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0303 - false_positives: 1009.0000 - val_loss: 0.0605 - val_false_positives: 438.0000
# Epoch 57/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0304 - false_positives: 980.0000 - val_loss: 0.0623 - val_false_positives: 408.0000
# Epoch 58/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0290 - false_positives: 968.0000 - val_loss: 0.0623 - val_false_positives: 408.0000
# Epoch 59/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0290 - false_positives: 959.0000 - val_loss: 0.0609 - val_false_positives: 424.0000
# Epoch 60/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0283 - false_positives: 951.0000 - val_loss: 0.0624 - val_false_positives: 370.0000
# Epoch 61/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0276 - false_positives: 911.0000 - val_loss: 0.0618 - val_false_positives: 414.0000
# Epoch 62/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0279 - false_positives: 925.0000 - val_loss: 0.0652 - val_false_positives: 412.0000
# Epoch 63/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0278 - false_positives: 956.0000 - val_loss: 0.0646 - val_false_positives: 479.0000
# Epoch 64/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0289 - false_positives: 990.0000 - val_loss: 0.0627 - val_false_positives: 430.0000
# Epoch 65/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0270 - false_positives: 919.0000 - val_loss: 0.0628 - val_false_positives: 393.0000
# Epoch 66/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0270 - false_positives: 944.0000 - val_loss: 0.0629 - val_false_positives: 421.0000
# Epoch 67/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0265 - false_positives: 917.0000 - val_loss: 0.0637 - val_false_positives: 397.0000
# Epoch 68/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0265 - false_positives: 915.0000 - val_loss: 0.0637 - val_false_positives: 412.0000
# Epoch 69/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0258 - false_positives: 877.0000 - val_loss: 0.0638 - val_false_positives: 389.0000
# Epoch 70/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0251 - false_positives: 822.0000 - val_loss: 0.0699 - val_false_positives: 447.0000
# Epoch 71/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0253 - false_positives: 877.0000 - val_loss: 0.0738 - val_false_positives: 432.0000
# Epoch 72/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0250 - false_positives: 888.0000 - val_loss: 0.0656 - val_false_positives: 386.0000
# Epoch 73/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0247 - false_positives: 847.0000 - val_loss: 0.0661 - val_false_positives: 397.0000
# Epoch 74/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0246 - false_positives: 836.0000 - val_loss: 0.0667 - val_false_positives: 423.0000
# Epoch 75/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0238 - false_positives: 801.0000 - val_loss: 0.0682 - val_false_positives: 443.0000
# Epoch 76/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0235 - false_positives: 832.0000 - val_loss: 0.0697 - val_false_positives: 408.0000
# Epoch 77/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0242 - false_positives: 815.0000 - val_loss: 0.0693 - val_false_positives: 439.0000
# Epoch 78/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0234 - false_positives: 825.0000 - val_loss: 0.0695 - val_false_positives: 404.0000
# Epoch 79/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0231 - false_positives: 813.0000 - val_loss: 0.0710 - val_false_positives: 470.0000
# Epoch 80/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0227 - false_positives: 797.0000 - val_loss: 0.0706 - val_false_positives: 413.0000
# Epoch 81/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0222 - false_positives: 751.0000 - val_loss: 0.0737 - val_false_positives: 475.0000
# Epoch 82/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0228 - false_positives: 815.0000 - val_loss: 0.0714 - val_false_positives: 431.0000
# Epoch 83/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0228 - false_positives: 818.0000 - val_loss: 0.0721 - val_false_positives: 411.0000
# Epoch 84/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0216 - false_positives: 777.0000 - val_loss: 0.0739 - val_false_positives: 398.0000
# Epoch 85/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0228 - false_positives: 771.0000 - val_loss: 0.0752 - val_false_positives: 487.0000
# Epoch 86/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0212 - false_positives: 739.0000 - val_loss: 0.0723 - val_false_positives: 422.0000
# Epoch 87/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0212 - false_positives: 745.0000 - val_loss: 0.0729 - val_false_positives: 418.0000
# Epoch 88/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0210 - false_positives: 708.0000 - val_loss: 0.0771 - val_false_positives: 433.0000
# Epoch 89/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0207 - false_positives: 711.0000 - val_loss: 0.0748 - val_false_positives: 439.0000
# Epoch 90/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0210 - false_positives: 753.0000 - val_loss: 0.0754 - val_false_positives: 441.0000
# Epoch 91/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0204 - false_positives: 735.0000 - val_loss: 0.0755 - val_false_positives: 423.0000
# Epoch 92/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0204 - false_positives: 706.0000 - val_loss: 0.0787 - val_false_positives: 469.0000
# Epoch 93/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0203 - false_positives: 742.0000 - val_loss: 0.0766 - val_false_positives: 412.0000
# Epoch 94/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0198 - false_positives: 687.0000 - val_loss: 0.0770 - val_false_positives: 453.0000
# Epoch 95/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0192 - false_positives: 688.0000 - val_loss: 0.0792 - val_false_positives: 446.0000
# Epoch 96/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0191 - false_positives: 676.0000 - val_loss: 0.0782 - val_false_positives: 422.0000
# Epoch 97/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0193 - false_positives: 698.0000 - val_loss: 0.0787 - val_false_positives: 419.0000
# Epoch 98/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0188 - false_positives: 665.0000 - val_loss: 0.0816 - val_false_positives: 465.0000
# Epoch 99/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0188 - false_positives: 672.0000 - val_loss: 0.0817 - val_false_positives: 440.0000
# Epoch 100/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0187 - false_positives: 672.0000 - val_loss: 0.0801 - val_false_positives: 426.0000
# Epoch 101/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0185 - false_positives: 669.0000 - val_loss: 0.0808 - val_false_positives: 465.0000
# Epoch 102/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0183 - false_positives: 674.0000 - val_loss: 0.0821 - val_false_positives: 474.0000
# Epoch 103/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0188 - false_positives: 688.0000 - val_loss: 0.0829 - val_false_positives: 444.0000
# Epoch 104/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0181 - false_positives: 651.0000 - val_loss: 0.0850 - val_false_positives: 462.0000
# Epoch 105/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0184 - false_positives: 682.0000 - val_loss: 0.0906 - val_false_positives: 504.0000
# Epoch 106/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0178 - false_positives: 635.0000 - val_loss: 0.0853 - val_false_positives: 451.0000
# Epoch 107/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0172 - false_positives: 610.0000 - val_loss: 0.0879 - val_false_positives: 472.0000
# Epoch 108/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0177 - false_positives: 663.0000 - val_loss: 0.0888 - val_false_positives: 438.0000
# Epoch 109/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0178 - false_positives: 638.0000 - val_loss: 0.0861 - val_false_positives: 441.0000
# Epoch 110/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0168 - false_positives: 619.0000 - val_loss: 0.0876 - val_false_positives: 451.0000
# Epoch 111/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0171 - false_positives: 603.0000 - val_loss: 0.0902 - val_false_positives: 463.0000
# Epoch 112/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0170 - false_positives: 627.0000 - val_loss: 0.0881 - val_false_positives: 450.0000
# Epoch 113/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0174 - false_positives: 636.0000 - val_loss: 0.0898 - val_false_positives: 477.0000
# Epoch 114/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0168 - false_positives: 589.0000 - val_loss: 0.0916 - val_false_positives: 480.0000
# Epoch 115/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0158 - false_positives: 560.0000 - val_loss: 0.0901 - val_false_positives: 424.0000
# Epoch 116/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0156 - false_positives: 565.0000 - val_loss: 0.0919 - val_false_positives: 452.0000
# Epoch 117/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0184 - false_positives: 676.0000 - val_loss: 0.0926 - val_false_positives: 457.0000
# Epoch 118/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0155 - false_positives: 546.0000 - val_loss: 0.0922 - val_false_positives: 436.0000
# Epoch 119/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0154 - false_positives: 522.0000 - val_loss: 0.0941 - val_false_positives: 459.0000
# Epoch 120/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0177 - false_positives: 634.0000 - val_loss: 0.0940 - val_false_positives: 443.0000
# Epoch 121/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0153 - false_positives: 545.0000 - val_loss: 0.0934 - val_false_positives: 449.0000
# Epoch 122/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0150 - false_positives: 514.0000 - val_loss: 0.0944 - val_false_positives: 436.0000
# Epoch 123/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0145 - false_positives: 512.0000 - val_loss: 0.0944 - val_false_positives: 426.0000
# Epoch 124/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0147 - false_positives: 511.0000 - val_loss: 0.0986 - val_false_positives: 470.0000
# Epoch 125/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0152 - false_positives: 510.0000 - val_loss: 0.0968 - val_false_positives: 451.0000
# Epoch 126/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0159 - false_positives: 579.0000 - val_loss: 0.0969 - val_false_positives: 439.0000
# Epoch 127/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0139 - false_positives: 489.0000 - val_loss: 0.0994 - val_false_positives: 453.0000
# Epoch 128/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0144 - false_positives: 526.0000 - val_loss: 0.0990 - val_false_positives: 452.0000
# Epoch 129/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0142 - false_positives: 495.0000 - val_loss: 0.0994 - val_false_positives: 465.0000
# Epoch 130/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0142 - false_positives: 503.0000 - val_loss: 0.1028 - val_false_positives: 433.0000
# Epoch 131/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0140 - false_positives: 497.0000 - val_loss: 0.0996 - val_false_positives: 437.0000
# Epoch 132/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0139 - false_positives: 491.0000 - val_loss: 0.1024 - val_false_positives: 439.0000
# Epoch 133/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0138 - false_positives: 490.0000 - val_loss: 0.1036 - val_false_positives: 503.0000
# Epoch 134/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0135 - false_positives: 486.0000 - val_loss: 0.1008 - val_false_positives: 460.0000
# Epoch 135/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0145 - false_positives: 529.0000 - val_loss: 0.1037 - val_false_positives: 462.0000
# Epoch 136/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0138 - false_positives: 474.0000 - val_loss: 0.1055 - val_false_positives: 479.0000
# Epoch 137/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0141 - false_positives: 513.0000 - val_loss: 0.1056 - val_false_positives: 470.0000
# Epoch 138/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0136 - false_positives: 477.0000 - val_loss: 0.1057 - val_false_positives: 417.0000
# Epoch 139/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0131 - false_positives: 467.0000 - val_loss: 0.1079 - val_false_positives: 501.0000
# Epoch 140/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0125 - false_positives: 459.0000 - val_loss: 0.1066 - val_false_positives: 461.0000
# Epoch 141/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0126 - false_positives: 447.0000 - val_loss: 0.1084 - val_false_positives: 477.0000
# Epoch 142/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0130 - false_positives: 487.0000 - val_loss: 0.1059 - val_false_positives: 484.0000
# Epoch 143/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0123 - false_positives: 434.0000 - val_loss: 0.1085 - val_false_positives: 470.0000
# Epoch 144/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0126 - false_positives: 457.0000 - val_loss: 0.1122 - val_false_positives: 487.0000
# Epoch 145/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0128 - false_positives: 454.0000 - val_loss: 0.1103 - val_false_positives: 476.0000
# Epoch 146/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0124 - false_positives: 445.0000 - val_loss: 0.1126 - val_false_positives: 483.0000
# Epoch 147/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0120 - false_positives: 438.0000 - val_loss: 0.1116 - val_false_positives: 458.0000
# Epoch 148/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0129 - false_positives: 460.0000 - val_loss: 0.1109 - val_false_positives: 457.0000
# Epoch 149/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0127 - false_positives: 467.0000 - val_loss: 0.1127 - val_false_positives: 427.0000
# Epoch 150/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0114 - false_positives: 381.0000 - val_loss: 0.1144 - val_false_positives: 492.0000
# Epoch 151/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0162 - false_positives: 597.0000 - val_loss: 0.1187 - val_false_positives: 484.0000
# Epoch 152/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0121 - false_positives: 438.0000 - val_loss: 0.1133 - val_false_positives: 462.0000
# Epoch 153/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0111 - false_positives: 394.0000 - val_loss: 0.1128 - val_false_positives: 439.0000
# Epoch 154/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0119 - false_positives: 433.0000 - val_loss: 0.1146 - val_false_positives: 439.0000
# Epoch 155/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0113 - false_positives: 391.0000 - val_loss: 0.1150 - val_false_positives: 433.0000
# Epoch 156/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0111 - false_positives: 396.0000 - val_loss: 0.1168 - val_false_positives: 417.0000
# Epoch 157/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0117 - false_positives: 416.0000 - val_loss: 0.1169 - val_false_positives: 454.0000
# Epoch 158/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0110 - false_positives: 379.0000 - val_loss: 0.1182 - val_false_positives: 446.0000
# Epoch 159/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0111 - false_positives: 394.0000 - val_loss: 0.1185 - val_false_positives: 488.0000
# Epoch 160/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0106 - false_positives: 383.0000 - val_loss: 0.1207 - val_false_positives: 442.0000
# Epoch 161/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0110 - false_positives: 393.0000 - val_loss: 0.1229 - val_false_positives: 466.0000
# Epoch 162/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0113 - false_positives: 422.0000 - val_loss: 0.1179 - val_false_positives: 474.0000
# Epoch 163/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0112 - false_positives: 421.0000 - val_loss: 0.1224 - val_false_positives: 448.0000
# Epoch 164/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0108 - false_positives: 393.0000 - val_loss: 0.1265 - val_false_positives: 444.0000
# Epoch 165/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0113 - false_positives: 410.0000 - val_loss: 0.1234 - val_false_positives: 479.0000
# Epoch 166/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0107 - false_positives: 392.0000 - val_loss: 0.1232 - val_false_positives: 443.0000
# Epoch 167/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0098 - false_positives: 342.0000 - val_loss: 0.1262 - val_false_positives: 437.0000
# Epoch 168/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0101 - false_positives: 342.0000 - val_loss: 0.1269 - val_false_positives: 501.0000
# Epoch 169/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0105 - false_positives: 400.0000 - val_loss: 0.1355 - val_false_positives: 491.0000
# Epoch 170/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0153 - false_positives: 511.0000 - val_loss: 0.1239 - val_false_positives: 483.0000
# Epoch 171/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0118 - false_positives: 429.0000 - val_loss: 0.1264 - val_false_positives: 470.0000
# Epoch 172/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0119 - false_positives: 443.0000 - val_loss: 0.1258 - val_false_positives: 469.0000
# Epoch 173/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0096 - false_positives: 326.0000 - val_loss: 0.1286 - val_false_positives: 468.0000
# Epoch 174/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0098 - false_positives: 342.0000 - val_loss: 0.1282 - val_false_positives: 443.0000
# Epoch 175/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0091 - false_positives: 312.0000 - val_loss: 0.1276 - val_false_positives: 441.0000
# Epoch 176/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0095 - false_positives: 335.0000 - val_loss: 0.1335 - val_false_positives: 440.0000
# Epoch 177/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0131 - false_positives: 434.0000 - val_loss: 0.1291 - val_false_positives: 425.0000
# Epoch 178/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0091 - false_positives: 311.0000 - val_loss: 0.1319 - val_false_positives: 460.0000
# Epoch 179/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0102 - false_positives: 363.0000 - val_loss: 0.1294 - val_false_positives: 462.0000
# Epoch 180/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0093 - false_positives: 323.0000 - val_loss: 0.1323 - val_false_positives: 471.0000
# Epoch 181/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0090 - false_positives: 315.0000 - val_loss: 0.1330 - val_false_positives: 443.0000
# Epoch 182/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0091 - false_positives: 332.0000 - val_loss: 0.1326 - val_false_positives: 470.0000
# Epoch 183/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0089 - false_positives: 325.0000 - val_loss: 0.1357 - val_false_positives: 485.0000
# Epoch 184/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0092 - false_positives: 322.0000 - val_loss: 0.1391 - val_false_positives: 526.0000
# Epoch 185/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0088 - false_positives: 301.0000 - val_loss: 0.1370 - val_false_positives: 462.0000
# Epoch 186/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0089 - false_positives: 320.0000 - val_loss: 0.1379 - val_false_positives: 488.0000
# Epoch 187/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0088 - false_positives: 310.0000 - val_loss: 0.1380 - val_false_positives: 495.0000
# Epoch 188/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0091 - false_positives: 344.0000 - val_loss: 0.1378 - val_false_positives: 470.0000
# Epoch 189/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0087 - false_positives: 322.0000 - val_loss: 0.1407 - val_false_positives: 482.0000
# Epoch 190/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0090 - false_positives: 327.0000 - val_loss: 0.1406 - val_false_positives: 449.0000
# Epoch 191/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0085 - false_positives: 295.0000 - val_loss: 0.1417 - val_false_positives: 473.0000
# Epoch 192/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0079 - false_positives: 276.0000 - val_loss: 0.1461 - val_false_positives: 524.0000
# Epoch 193/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0096 - false_positives: 366.0000 - val_loss: 0.1427 - val_false_positives: 464.0000
# Epoch 194/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0085 - false_positives: 324.0000 - val_loss: 0.1461 - val_false_positives: 466.0000
# Epoch 195/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0116 - false_positives: 441.0000 - val_loss: 0.1428 - val_false_positives: 467.0000
# Epoch 196/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0081 - false_positives: 283.0000 - val_loss: 0.1451 - val_false_positives: 495.0000
# Epoch 197/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0080 - false_positives: 271.0000 - val_loss: 0.1480 - val_false_positives: 527.0000
# Epoch 198/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0082 - false_positives: 289.0000 - val_loss: 0.1469 - val_false_positives: 464.0000
# Epoch 199/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0079 - false_positives: 274.0000 - val_loss: 0.1473 - val_false_positives: 461.0000
# Epoch 200/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0074 - false_positives: 253.0000 - val_loss: 0.1490 - val_false_positives: 451.0000
# Epoch 201/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0083 - false_positives: 304.0000 - val_loss: 0.1559 - val_false_positives: 516.0000
# Epoch 202/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0147 - false_positives: 495.0000 - val_loss: 0.1443 - val_false_positives: 459.0000
# Epoch 203/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 239.0000 - val_loss: 0.1486 - val_false_positives: 507.0000
# Epoch 204/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0075 - false_positives: 265.0000 - val_loss: 0.1485 - val_false_positives: 480.0000
# Epoch 205/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0104 - false_positives: 348.0000 - val_loss: 0.1503 - val_false_positives: 465.0000
# Epoch 206/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 254.0000 - val_loss: 0.1515 - val_false_positives: 488.0000
# Epoch 207/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0078 - false_positives: 285.0000 - val_loss: 0.1540 - val_false_positives: 505.0000
# Epoch 208/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 256.0000 - val_loss: 0.1516 - val_false_positives: 490.0000
# Epoch 209/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 257.0000 - val_loss: 0.1537 - val_false_positives: 499.0000
# Epoch 210/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0067 - false_positives: 238.0000 - val_loss: 0.1558 - val_false_positives: 465.0000
# Epoch 211/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 265.0000 - val_loss: 0.1551 - val_false_positives: 490.0000
# Epoch 212/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0080 - false_positives: 279.0000 - val_loss: 0.1573 - val_false_positives: 504.0000
# Epoch 213/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0070 - false_positives: 249.0000 - val_loss: 0.1548 - val_false_positives: 484.0000
# Epoch 214/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0069 - false_positives: 262.0000 - val_loss: 0.1591 - val_false_positives: 481.0000
# Epoch 215/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0124 - false_positives: 392.0000 - val_loss: 0.1553 - val_false_positives: 482.0000
# Epoch 216/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0063 - false_positives: 224.0000 - val_loss: 0.1569 - val_false_positives: 463.0000
# Epoch 217/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0074 - false_positives: 264.0000 - val_loss: 0.1592 - val_false_positives: 476.0000
# Epoch 218/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0068 - false_positives: 238.0000 - val_loss: 0.1564 - val_false_positives: 465.0000
# Epoch 219/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0070 - false_positives: 246.0000 - val_loss: 0.1600 - val_false_positives: 438.0000
# Epoch 220/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0069 - false_positives: 238.0000 - val_loss: 0.1633 - val_false_positives: 474.0000
# Epoch 221/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 259.0000 - val_loss: 0.1621 - val_false_positives: 524.0000
# Epoch 222/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 266.0000 - val_loss: 0.1638 - val_false_positives: 501.0000
# Epoch 223/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0065 - false_positives: 219.0000 - val_loss: 0.1648 - val_false_positives: 462.0000
# Epoch 224/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0064 - false_positives: 229.0000 - val_loss: 0.1669 - val_false_positives: 468.0000
# Epoch 225/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0071 - false_positives: 263.0000 - val_loss: 0.1663 - val_false_positives: 499.0000
# Epoch 226/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0093 - false_positives: 361.0000 - val_loss: 0.1633 - val_false_positives: 481.0000
# Epoch 227/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0064 - false_positives: 223.0000 - val_loss: 0.1656 - val_false_positives: 454.0000
# Epoch 228/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0060 - false_positives: 215.0000 - val_loss: 0.1654 - val_false_positives: 446.0000
# Epoch 229/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0061 - false_positives: 221.0000 - val_loss: 0.1683 - val_false_positives: 461.0000
# Epoch 230/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 270.0000 - val_loss: 0.1689 - val_false_positives: 454.0000
# Epoch 231/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0074 - false_positives: 254.0000 - val_loss: 0.1791 - val_false_positives: 488.0000
# Epoch 232/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0109 - false_positives: 380.0000 - val_loss: 0.1690 - val_false_positives: 493.0000
# Epoch 233/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0062 - false_positives: 213.0000 - val_loss: 0.1688 - val_false_positives: 468.0000
# Epoch 234/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0056 - false_positives: 190.0000 - val_loss: 0.1692 - val_false_positives: 458.0000
# Epoch 235/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0057 - false_positives: 205.0000 - val_loss: 0.1704 - val_false_positives: 452.0000
# Epoch 236/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0052 - false_positives: 171.0000 - val_loss: 0.1743 - val_false_positives: 467.0000
# Epoch 237/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0059 - false_positives: 204.0000 - val_loss: 0.1728 - val_false_positives: 449.0000
# Epoch 238/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0061 - false_positives: 203.0000 - val_loss: 0.1711 - val_false_positives: 454.0000
# Epoch 239/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0056 - false_positives: 175.0000 - val_loss: 0.1757 - val_false_positives: 472.0000
# Epoch 240/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 281.0000 - val_loss: 0.1781 - val_false_positives: 454.0000
# Epoch 241/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0056 - false_positives: 186.0000 - val_loss: 0.1783 - val_false_positives: 456.0000
# Epoch 242/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0059 - false_positives: 210.0000 - val_loss: 0.1751 - val_false_positives: 454.0000
# Epoch 243/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0060 - false_positives: 214.0000 - val_loss: 0.1755 - val_false_positives: 440.0000
# Epoch 244/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0059 - false_positives: 215.0000 - val_loss: 0.1825 - val_false_positives: 495.0000
# Epoch 245/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0069 - false_positives: 254.0000 - val_loss: 0.1811 - val_false_positives: 465.0000
# Epoch 246/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0056 - false_positives: 185.0000 - val_loss: 0.1792 - val_false_positives: 495.0000
# Epoch 247/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0063 - false_positives: 235.0000 - val_loss: 0.1916 - val_false_positives: 532.0000
# Epoch 248/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 262.0000 - val_loss: 0.1894 - val_false_positives: 508.0000
# Epoch 249/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0108 - false_positives: 383.0000 - val_loss: 0.1784 - val_false_positives: 475.0000
# Epoch 250/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 175.0000 - val_loss: 0.1800 - val_false_positives: 485.0000
# Epoch 251/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0045 - false_positives: 143.0000 - val_loss: 0.1835 - val_false_positives: 457.0000
# Epoch 252/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0048 - false_positives: 163.0000 - val_loss: 0.1848 - val_false_positives: 462.0000
# Epoch 253/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0049 - false_positives: 162.0000 - val_loss: 0.1842 - val_false_positives: 468.0000
# Epoch 254/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0050 - false_positives: 168.0000 - val_loss: 0.1828 - val_false_positives: 472.0000
# Epoch 255/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0048 - false_positives: 181.0000 - val_loss: 0.1837 - val_false_positives: 479.0000
# Epoch 256/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0048 - false_positives: 163.0000 - val_loss: 0.1862 - val_false_positives: 469.0000
# Epoch 257/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0063 - false_positives: 241.0000 - val_loss: 0.1899 - val_false_positives: 506.0000
# Epoch 258/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0072 - false_positives: 279.0000 - val_loss: 0.1877 - val_false_positives: 461.0000
# Epoch 259/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0045 - false_positives: 139.0000 - val_loss: 0.1925 - val_false_positives: 492.0000
# Epoch 260/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0051 - false_positives: 182.0000 - val_loss: 0.1912 - val_false_positives: 482.0000
# Epoch 261/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0049 - false_positives: 165.0000 - val_loss: 0.1917 - val_false_positives: 482.0000
# Epoch 262/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0066 - false_positives: 237.0000 - val_loss: 0.1951 - val_false_positives: 503.0000
# Epoch 263/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0052 - false_positives: 184.0000 - val_loss: 0.1929 - val_false_positives: 467.0000
# Epoch 264/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0075 - false_positives: 279.0000 - val_loss: 0.1932 - val_false_positives: 438.0000
# Epoch 265/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0058 - false_positives: 216.0000 - val_loss: 0.1939 - val_false_positives: 479.0000
# Epoch 266/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0045 - false_positives: 155.0000 - val_loss: 0.1943 - val_false_positives: 476.0000
# Epoch 267/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0049 - false_positives: 164.0000 - val_loss: 0.1984 - val_false_positives: 512.0000
# Epoch 268/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0039 - false_positives: 126.0000 - val_loss: 0.1978 - val_false_positives: 468.0000
# Epoch 269/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0065 - false_positives: 227.0000 - val_loss: 0.1996 - val_false_positives: 491.0000
# Epoch 270/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0060 - false_positives: 231.0000 - val_loss: 0.2022 - val_false_positives: 479.0000
# Epoch 271/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 186.0000 - val_loss: 0.1996 - val_false_positives: 519.0000
# Epoch 272/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0041 - false_positives: 140.0000 - val_loss: 0.2015 - val_false_positives: 468.0000
# Epoch 273/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0046 - false_positives: 167.0000 - val_loss: 0.1986 - val_false_positives: 486.0000
# Epoch 274/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0060 - false_positives: 199.0000 - val_loss: 0.2017 - val_false_positives: 491.0000
# Epoch 275/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0045 - false_positives: 152.0000 - val_loss: 0.2175 - val_false_positives: 513.0000
# Epoch 276/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 191.0000 - val_loss: 0.2093 - val_false_positives: 491.0000
# Epoch 277/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0048 - false_positives: 159.0000 - val_loss: 0.2059 - val_false_positives: 465.0000
# Epoch 278/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0044 - false_positives: 161.0000 - val_loss: 0.2070 - val_false_positives: 479.0000
# Epoch 279/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0073 - false_positives: 269.0000 - val_loss: 0.2025 - val_false_positives: 477.0000
# Epoch 280/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0045 - false_positives: 155.0000 - val_loss: 0.2020 - val_false_positives: 484.0000
# Epoch 281/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0034 - false_positives: 98.0000 - val_loss: 0.2057 - val_false_positives: 484.0000
# Epoch 282/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0051 - false_positives: 208.0000 - val_loss: 0.2065 - val_false_positives: 502.0000
# Epoch 283/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0041 - false_positives: 152.0000 - val_loss: 0.2122 - val_false_positives: 479.0000
# Epoch 284/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0088 - false_positives: 327.0000 - val_loss: 0.2160 - val_false_positives: 512.0000
# Epoch 285/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0049 - false_positives: 168.0000 - val_loss: 0.2095 - val_false_positives: 468.0000
# Epoch 286/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0037 - false_positives: 122.0000 - val_loss: 0.2081 - val_false_positives: 472.0000
# Epoch 287/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0037 - false_positives: 126.0000 - val_loss: 0.2054 - val_false_positives: 478.0000
# Epoch 288/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0061 - false_positives: 233.0000 - val_loss: 0.2077 - val_false_positives: 466.0000
# Epoch 289/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0053 - false_positives: 190.0000 - val_loss: 0.2080 - val_false_positives: 443.0000
# Epoch 290/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0037 - false_positives: 122.0000 - val_loss: 0.2116 - val_false_positives: 478.0000
# Epoch 291/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0046 - false_positives: 163.0000 - val_loss: 0.2126 - val_false_positives: 481.0000
# Epoch 292/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0040 - false_positives: 133.0000 - val_loss: 0.2126 - val_false_positives: 448.0000
# Epoch 293/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0061 - false_positives: 223.0000 - val_loss: 0.2103 - val_false_positives: 464.0000
# Epoch 294/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0068 - false_positives: 235.0000 - val_loss: 0.2133 - val_false_positives: 479.0000
# Epoch 295/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0048 - false_positives: 181.0000 - val_loss: 0.2088 - val_false_positives: 455.0000
# Epoch 296/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0046 - false_positives: 162.0000 - val_loss: 0.2132 - val_false_positives: 479.0000
# Epoch 297/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0032 - false_positives: 107.0000 - val_loss: 0.2158 - val_false_positives: 501.0000
# Epoch 298/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0047 - false_positives: 158.0000 - val_loss: 0.2148 - val_false_positives: 509.0000
# Epoch 299/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0031 - false_positives: 100.0000 - val_loss: 0.2163 - val_false_positives: 468.0000
# Epoch 300/300
# 217/217 [==============================] - 1s 3ms/step - loss: 0.0039 - false_positives: 127.0000 - val_loss: 0.2182 - val_false_positives: 542.0000

# %%
pred_y = model.predict(X_test)
# Out:
# 118/118 [==============================] - 0s 1ms/step

# %%
c= 5

plt.plot(y_test[sequence_length*c])
plt.plot(pred_y[sequence_length*c])

# %%
# Get the plethysmographic data and remove the last element for shape purposes
plety = test['plety'].iloc[:-1]


# Calculate actual peak values from the test data
actual_values = plety[test['x_prime_peak']==1]

# Calculate the indeces where the actual values are present 
# so that we can plot the point from the test at that index
indices = actual_values.index

# Calculate the predictions:
# We have 3700+ sequences of 60 points
# The first sequence of 60 points is saved in the predictions array
# for each one of the net sequences we save the last element to the array
# we end up with a prediction array with all the predicted values for each plety index value
predictions = np.array([])

for ind, i in enumerate(pred_y):
    if ind == 0:
        predictions = np.append(predictions, pred_y[ind])
    else:
        predictions = np.append(predictions, pred_y[ind][-1])
        
# Calculate the indeces where the predicted values are present 
# so that we can plot the point from the test at that index
indices_pred = np.where(np.isin(predictions, predictions[predictions>0.1]))[0]

range_min = 0
range_max = 1500

# Set the figure size
plt.figure(figsize=(20, 10))

# Plotting code
# Plot the plety data
plt.plot(plety[range_min:range_max])

# Plot the points from the plety where actual values have a peak, (==1)
plt.scatter(np.array(indices[indices<range_max]), actual_values[range_min:len(np.array(indices[indices<range_max]))], c="black", label='actual')

# Plot the points from the plety where predicted values have a peak, (==1)
plt.scatter(np.array(indices_pred[indices_pred<range_max]), plety[indices_pred][range_min:len(np.array(indices_pred[indices_pred<range_max]))],c="red", label='predicted')

# Display the legend
plt.legend()

plt.show()

# %%
pred_y = model.predict(X_test) > 0.5
# Out:
# 118/118 [==============================] - 0s 1ms/step

# %%
import seaborn as sns

y_test = y_test.flatten()
pred_y = pred_y.flatten()

mat = np.array(confusion_matrix(y_test, pred_y), dtype=float)
mat[0,0] = mat[0,0]/len(y_test[y_test == 0])
mat[1,1] = mat[1,1]/len(y_test[y_test == 1])

mat[0,1] = mat[0,1]/len(y_test[y_test == 0])
mat[1,0] = mat[1,0]/len(y_test[y_test == 1])
labels = ['0', '1']

sns.heatmap(mat, square=True, annot=True, cbar=False, cmap='Blues',
            xticklabels=labels, yticklabels=labels)
 
plt.xlabel('Predicted label')
plt.ylabel('Actual label')
plt.show()
